# %% [markdown]
# ## What Is Agentic Ai? ##

# %% [markdown]
# **The type of Ai,that take a task or goal from yhe user and then work  to complete task on its own with minimal human intervention.It plans,take action,adapt to changes and seeks help when necessary.**
