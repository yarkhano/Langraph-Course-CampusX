# %% [markdown]
# ## Persistance-> Store and restore state in Lnagraph over the time.##

# %% [markdown]
# ## Persistance not only store the state start or end also store every state (intermediate state) too. ##

# %% [markdown]
# **Checkpointer are the the things that store the state t every super step**

# %% [markdown]
# **To every conversation a thread id is being assigned so if you want to fetch that specific conversation the thread id is used**
