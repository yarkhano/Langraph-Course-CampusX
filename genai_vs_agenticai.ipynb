# %% [markdown]
# ## Ai Agent-> Can take actions,Context aware (memmory),Proactive (Initiate by self or take action before the something happen),context aware ,adaptabile(identify problem and propose solution) ##

# %% [markdown]
# ## End Goal is given to ai agent and it finish byself asking human just an approval ##

# %% [markdown]
# **In agents we have memmory,Tools,planing and LLMs**

# %% [markdown]
# **Generative ai is capability while agentic ai is behavior.**
